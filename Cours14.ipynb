# %% [markdown]
# <a href="https://colab.research.google.com/github/Romane-lrnt/GitConcepts/blob/main/Cours14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
pd.read_json?

# %%
df=pd.read_csv("/content/Educational_Attainment_20231027.csv")

# %%
df.head(5)
# Out:
#         Geography Geography type  Year  Less Than High School Graduate  \
# 0        Atherton           Town  2014                            13.6
# 1           Colma           Town  2014                             6.3
# 2     Foster City           City  2014                            11.9
# 3  Portola Valley           Town  2014                            48.1
# 4    Redwood City           City  2014                            16.4
#
#    High School Graduate  Some College or Associate's Degree  \
# 0                  12.3                                 2.7
# 1                   6.4                                10.4
# 2                   9.7                                 2.0
# 3                   0.0                                 0.0
# 4                  10.6                                 6.6
#
#    Bachelor's Degree or Higher                Location 1
# 0                          3.5       (37.458611, -122.2)
# 1                          2.4  (37.678889, -122.455556)
# ...

# %%
df.tail(10)
# Out:
#           Geography Geography type  Year  Less Than High School Graduate  \
# 22         Loma Mar            CDP  2014                           100.0
# 23         Woodside           Town  2014                             0.0
# 24    Half Moon Bay           City  2014                             9.5
# 25        San Bruno           City  2014                             7.7
# 26        Pescadero            CDP  2014                            44.4
# 27       El Granada            CDP  2014                             9.2
# 28  West Menlo Park            CDP  2014                            37.8
# 29          Montara            CDP  2014                             3.3
# 30       Burlingame           City  2014                            20.1
# 31         La Honda            CDP  2014                             0.0
#
#     High School Graduate  Some College or Associate's Degree  \
# 22                   0.0                                 0.0
# ...

# %%
df.describe()
# Out:
#          Year  Less Than High School Graduate  High School Graduate  \
# count    32.0                        32.00000             32.000000
# mean   2014.0                        17.80000              6.462500
# std       0.0                        19.29944              4.693905
# min    2014.0                         0.00000              0.000000
# 25%    2014.0                         6.82500              1.925000
# 50%    2014.0                        13.90000              7.750000
# 75%    2014.0                        20.97500              9.450000
# max    2014.0                       100.00000             16.400000
#
#        Some College or Associate's Degree  Bachelor's Degree or Higher
# count                           32.000000                    32.000000
# mean                             5.946875                     2.856250
# std                              4.728430                     1.873919
# min                              0.000000                     0.000000
# ...

# %%
df.dtypes
# Out:
# Geography                              object
# Geography type                         object
# Year                                    int64
# Less Than High School Graduate        float64
# High School Graduate                  float64
# Some College or Associate's Degree    float64
# Bachelor's Degree or Higher           float64
# Location 1                             object
# dtype: object

# %%
df.drop("Geography", axis=1).describe(include="all")
# Out:
#        Geography type    Year  Less Than High School Graduate  \
# count              32    32.0                        32.00000
# unique              3     NaN                             NaN
# top              City     NaN                             NaN
# freq               15     NaN                             NaN
# mean              NaN  2014.0                        17.80000
# std               NaN     0.0                        19.29944
# min               NaN  2014.0                         0.00000
# 25%               NaN  2014.0                         6.82500
# 50%               NaN  2014.0                        13.90000
# 75%               NaN  2014.0                        20.97500
# max               NaN  2014.0                       100.00000
#
#         High School Graduate  Some College or Associate's Degree  \
# count              32.000000                           32.000000
# unique                   NaN                                 NaN
# ...

# %%
df.columns=df.columns.str.replace(' ', '')
df.columns=df.columns.str.replace("'", "")

# %%
df.Geographytype.count()
# Out:
# 32

# %%
df.BachelorsDegreeorHigher.mean()
# Out:
# 2.85625

# %%
df.dtypes
# Out:
# Geography                         object
# Geographytype                     object
# Year                               int64
# LessThanHighSchoolGraduate       float64
# HighSchoolGraduate               float64
# SomeCollegeorAssociatesDegree    float64
# BachelorsDegreeorHigher          float64
# Location1                         object
# dtype: object

# %%
df.LessThanHighSchoolGraduate.value_counts()
# Out:
# 0.0      4
# 13.6     1
# 15.1     1
# 3.3      1
# 37.8     1
# 9.2      1
# 44.4     1
# 7.7      1
# 9.5      1
# 100.0    1
# 7.0      1
# 21.2     1
# 18.3     1
# 15.7     1
# 8.5      1
# 22.1     1
# 6.3      1
# 31.1     1
# 6.2      1
# 26.7     1
# 16.1     1
# 13.4     1
# 20.9     1
# 14.2     1
# 4.8      1
# 16.4     1
# 48.1     1
# 11.9     1
# 20.1     1
# Name: LessThanHighSchoolGraduate, dtype: int64

# %%
baby_names=pd.read_csv("/content/US_Baby_Names_right.csv")

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK   62.0
# 1       11350  11351   Madison  2004      F    AK   48.0
# 2       11351  11352    Hannah  2004      F    AK   46.0
# 3       11352  11353     Grace  2004      F    AK   44.0
# 4       11353  11354     Emily  2004      F    AK   41.0
# 5       11354  11355   Abigail  2004      F    AK   37.0
# 6       11355  11356    Olivia  2004      F    AK   33.0
# 7       11356  11357  Isabella  2004      F    AK   30.0
# 8       11357  11358    Alyssa  2004      F    AK   29.0
# 9       11358  11359    Sophia  2004      F    AK   28.0

# %%
baby_names=baby_names.drop("Unnamed: 0", axis=1)
baby_names=baby_names.drop("Id", axis=1)

# %%
baby_names.head(10)
# Out:
#        Name  Year Gender State  Count
# 0      Emma  2004      F    AK   62.0
# 1   Madison  2004      F    AK   48.0
# 2    Hannah  2004      F    AK   46.0
# 3     Grace  2004      F    AK   44.0
# 4     Emily  2004      F    AK   41.0
# 5   Abigail  2004      F    AK   37.0
# 6    Olivia  2004      F    AK   33.0
# 7  Isabella  2004      F    AK   30.0
# 8    Alyssa  2004      F    AK   29.0
# 9    Sophia  2004      F    AK   28.0

# %%
baby_names['Gender'].value_counts()
# Out:
# F    66017
# M    28301
# Name: Gender, dtype: int64

# %%
del baby_names['Year']
names=baby_names.groupby("Name").sum()
names.head()
# Out:
# <ipython-input-27-5089b5684d90>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   names=baby_names.groupby("Name").sum()
#          Count
# Name
# Aaden    187.0
# Aadhya    24.0
# Aadya     37.0
# Aahana    38.0
# Aalayah   18.0

# %%
print(names.shape)
# Out:
# (8923, 1)

# %%
names.sort_values("Count", ascending=0).head()
# Out:
#             Count
# Name
# Isabella  32009.0
# Emily     31480.0
# Sophia    27874.0
# Emma      24634.0
# Mia       22010.0
